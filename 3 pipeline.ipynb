# %%
import pandas as pd

# %%
df=pd.read_csv("processed_data.csv")
df
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7027    Male              0     Yes        Yes      24          Yes
# 7028  Female              0     Yes        Yes      72          Yes
# 7029  Female              0     Yes        Yes      11           No
# 7030    Male              1     Yes         No       4          Yes
# 7031    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
df2 = df.drop(['gender','PhoneService','MultipleLines','InternetService','StreamingTV','StreamingMovies'],axis = 1)

# %%
df2.head(2)
# Out:
#    SeniorCitizen Partner Dependents  tenure OnlineSecurity OnlineBackup  \
# 0              0     Yes         No       1             No          Yes
# 1              0      No         No      34            Yes           No
#
#   DeviceProtection TechSupport        Contract PaperlessBilling  \
# 0               No          No  Month-to-month              Yes
# 1              Yes          No        One year               No
#
#       PaymentMethod  MonthlyCharges  TotalCharges Churn
# 0  Electronic check           29.85         29.85    No
# 1      Mailed check           56.95       1889.50    No

# %%
X = df2.iloc[:,:-1]
y = df2['Churn']

# %%
from sklearn_pandas import DataFrameMapper
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.ensemble import RandomForestClassifier

# %%
dm = DataFrameMapper([
    (['Partner',LabelEncoder()]),
    (["Dependents",LabelEncoder()]),
    (["OnlineSecurity",LabelEncoder()]),(["OnlineBackup",LabelEncoder()]),
    (["DeviceProtection",LabelEncoder()]),(["TechSupport",LabelEncoder()]),
    (["Contract",LabelEncoder()]),(["PaperlessBilling",LabelEncoder()]),
    (["PaymentMethod",LabelEncoder()]),
])
dm
# Out:
# DataFrameMapper(drop_cols=[],
#                 features=[['Partner', LabelEncoder()],
#                           ['Dependents', LabelEncoder()],
#                           ['OnlineSecurity', LabelEncoder()],
#                           ['OnlineBackup', LabelEncoder()],
#                           ['DeviceProtection', LabelEncoder()],
#                           ['TechSupport', LabelEncoder()],
#                           ['Contract', LabelEncoder()],
#                           ['PaperlessBilling', LabelEncoder()],
#                           ['PaymentMethod', LabelEncoder()]])

# %%
ml = []
ml.append(['mapper',dm])
ml.append(['SC',StandardScaler()])
ml.append(['RF',RandomForestClassifier()])

# %%
ml
# Out:
# [['mapper',
#   DataFrameMapper(drop_cols=[],
#                   features=[['Partner', LabelEncoder()],
#                             ['Dependents', LabelEncoder()],
#                             ['OnlineSecurity', LabelEncoder()],
#                             ['OnlineBackup', LabelEncoder()],
#                             ['DeviceProtection', LabelEncoder()],
#                             ['TechSupport', LabelEncoder()],
#                             ['Contract', LabelEncoder()],
#                             ['PaperlessBilling', LabelEncoder()],
#                             ['PaymentMethod', LabelEncoder()]])],
#  ['SC', StandardScaler()],
#  ['RF', RandomForestClassifier()]]

# %%
from sklearn.pipeline import Pipeline
import warnings
warnings.filterwarnings('ignore')

# %%
model = Pipeline(ml)
model.fit(X,y)
# Out:
# Pipeline(steps=[('mapper',
#                  DataFrameMapper(drop_cols=[],
#                                  features=[['Partner', LabelEncoder()],
#                                            ['Dependents', LabelEncoder()],
#                                            ['OnlineSecurity', LabelEncoder()],
#                                            ['OnlineBackup', LabelEncoder()],
#                                            ['DeviceProtection', LabelEncoder()],
#                                            ['TechSupport', LabelEncoder()],
#                                            ['Contract', LabelEncoder()],
#                                            ['PaperlessBilling', LabelEncoder()],
#                                            ['PaymentMethod', LabelEncoder()]])),
#                 ('SC', StandardScaler()), ['RF', RandomForestClassifier()]])

# %%
dict(df2.iloc[25,:-1])
# Out:
# {'SeniorCitizen': 0,
#  'Partner': 'No',
#  'Dependents': 'No',
#  'tenure': 30,
#  'OnlineSecurity': 'Yes',
#  'OnlineBackup': 'Yes',
#  'DeviceProtection': 'No',
#  'TechSupport': 'No',
#  'Contract': 'Month-to-month',
#  'PaperlessBilling': 'Yes',
#  'PaymentMethod': 'Bank transfer (automatic)',
#  'MonthlyCharges': 55.3,
#  'TotalCharges': 1530.6}

# %%
import numpy as np
new_data=pd.DataFrame({'SeniorCitizen': np.int64(0),
 'Partner': 'No',
 'Dependents': 'No',
 'tenure': np.int64(30),
 'OnlineSecurity': 'Yes',
 'OnlineBackup': 'Yes',
 'DeviceProtection': 'No',
 'TechSupport': 'No',
 'Contract': 'Month-to-month',
 'PaperlessBilling': 'Yes',
 'PaymentMethod': 'Bank transfer (automatic)',
 'MonthlyCharges': np.float64(55.3),
 'TotalCharges': np.float64(1530.6)}, index=[0])
new_data
# Out:
#    SeniorCitizen Partner Dependents  tenure OnlineSecurity OnlineBackup  \
# 0              0      No         No      30            Yes          Yes
#
#   DeviceProtection TechSupport        Contract PaperlessBilling  \
# 0               No          No  Month-to-month              Yes
#
#                PaymentMethod  MonthlyCharges  TotalCharges
# 0  Bank transfer (automatic)            55.3        1530.6

# %%
model.predict(new_data)
# Out:
# array(['No'], dtype=object)

# %%
df2.iloc[25,-1]
# Out:
# 'No'

# %%
import pickle 
with open('final_model.sav',mode='wb') as f:
    pickle.dump(model,f)
